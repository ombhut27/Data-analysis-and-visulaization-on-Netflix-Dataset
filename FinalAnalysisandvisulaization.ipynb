# %% [markdown]
# # **Netflix Dataset**

# %% [markdown]
# Data Analysis and Visulaization with Python.

# %% [markdown]
# This Netflix Dataset has information about the TV Shows and Movies available on Netflix till 2021.
#
# This dataset is collected from Flixable which is a third-party Netflix search engine, and available on Kaggle website for free.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e1fe23e-362b-4ca8-bbd9-f815d2ec35de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e1fe23e-362b-4ca8-bbd9-f815d2ec35de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['netflix_titles.csv']))

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # **Getting some basic information about Dataset**

# %% [markdown]
# 1.head()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# 2.tail()

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# 3.shape

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# 4.size

# %%
df.size
# Out:
# 105684

# %% [markdown]
# 5.columns

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 6.dtypes

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# 7.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # **-----> Data cleaning and preprocessing**

# %% [markdown]
# # ----->> Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %% [markdown]
# duplicate()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # ----> Is there any Null Value present in any column ? Show with Heat-map.

# %% [markdown]
# isnull()

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # ----->Handling Missing Data

# %% [markdown]
# # 1.Filling the missing 'Country' value with 'United States'

# %%
df['country'].fillna('United States' , inplace=True)
df['country'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # 2.Filling the missing 'Rating' value with 'TV-MA'.

# %%
df['rating'].fillna('TV-MA' , inplace=True)
df['rating'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added        10
# release_year       0
# rating             0
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # 3.Filling the missing 'duration' time with '150 minute '.

# %%
df['duration'].fillna('150 minute' , inplace=True)
df['duration'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added        10
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # 4.Filling the missing 'date_added' value with 'september 20,2021'.

# %%
df['date_added'].fillna('september 20, 2021' , inplace=True)
df['date_added'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # 5.Filling the missing 'director' value with 'information is not avilable'.

# %%
df['director'].fillna('information is not avilable' , inplace=True)
df['director'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# # 6.Filling the missing 'cast' value with 'information is not avilable'.

# %%
df['cast'].fillna('Tom criuse,Tom Ellis' , inplace=True)
df['cast'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # **----> Questioning and Answering**

# %% [markdown]
# # Q.1. For 'The Conjuring', what is the Show Id and Who is the Director of this show ?

# %% [markdown]
# isin()

# %%
df.head()
# Out:
#   show_id     type                  title                     director  \
# 0      s1    Movie   Dick Johnson Is Dead              Kirsten Johnson
# 1      s2  TV Show          Blood & Water  information is not avilable
# 2      s3  TV Show              Ganglands              Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  information is not avilable
# 4      s5  TV Show           Kota Factory  information is not avilable
#
#                                                 cast        country  \
# 0                               Tom criuse,Tom Ellis  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                               Tom criuse,Tom Ellis  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df[df['title'].isin(['The Conjuring'])]
# Out:
#      show_id   type          title   director  \
# 1283   s1284  Movie  The Conjuring  James Wan
#
#                                                    cast        country  \
# 1283  Vera Farmiga, Patrick Wilson, Lili Taylor, Ron...  United States
#
#              date_added  release_year rating duration  \
# 1283  February 21, 2021          2013      R  112 min
#
#                      listed_in  \
# 1283  Horror Movies, Thrillers
#
#                                             description
# 1283  When a family starts experiencing supernatural...

# %%
df[df['title'].str.contains('The Conjuring')]    #To show all records of a particular string in any column
# Out:
#      show_id   type            title   director  \
# 1283   s1284  Movie    The Conjuring  James Wan
# 1284   s1285  Movie  The Conjuring 2  James Wan
#
#                                                    cast  \
# 1283  Vera Farmiga, Patrick Wilson, Lili Taylor, Ron...
# 1284  Patrick Wilson, Vera Farmiga, Madison Wolfe, F...
#
#                                     country         date_added  release_year  \
# 1283                          United States  February 21, 2021          2013
# 1284  Canada, United States, United Kingdom  February 21, 2021          2016
#
#      rating duration                 listed_in  \
# 1283      R  112 min  Horror Movies, Thrillers
# 1284      R  134 min             Horror Movies
#
#                                             description
# 1283  When a family starts experiencing supernatural...
# 1284  After her daughter unwittingly releases a male...

# %% [markdown]
# # Q.2. In which year highest number of the TV Shows & Movies were released ? count graph.

# %%
df.release_year.value_counts()[:20]
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# Name: release_year, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,6))
sns.countplot(y='release_year' ,order = df['release_year'].value_counts().index[0:20],data = df)
plt.title('Content Release in Years on Netflix Vs Count')
# Out:
# Text(0.5, 1.0, 'Content Release in Years on Netflix Vs Count')

# %% [markdown]
# # Q.3. How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %% [markdown]
# groupby()

# %%
df.head(2)
# Out:
#   show_id     type                 title                     director  \
# 0      s1    Movie  Dick Johnson Is Dead              Kirsten Johnson
# 1      s2  TV Show         Blood & Water  information is not avilable
#
#                                                 cast        country  \
# 0                               Tom criuse,Tom Ellis  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# countplot()

# %% [markdown]
# # Q.4. Show all the Movies that were released in year 2019.

# %% [markdown]
# Filtering

# %%
df[ (df['type'] == 'Movie') & (df['release_year']==2019) ]
# Out:
#      show_id   type                        title             director  \
# 90       s91  Movie               Paradise Hills     Alice Waddington
# 334     s335  Movie              Five Feet Apart       Justin Baldoni
# 348     s349  Movie                         Poms           Zara Hayes
# 378     s379  Movie              Fantastic Fungi   Louie Schwartzberg
# 389     s390  Movie                The Operative          Yuval Adler
# ...      ...    ...                          ...                  ...
# 8516   s8517  Movie    The Spy Who Fell to Earth      Thomas Meadmore
# 8631   s8632  Movie  Trixie Mattel: Moving Parts  Nicholas Zeig-Owens
# 8718   s8719  Movie       Westside vs. the World        Michael Fahey
# 8752   s8753  Movie                     Wish Man          Theo Davies
# 8756   s8757  Movie                    Woodstock        Barak Goodman
#
#                                                    cast  \
# 90    Emma Roberts, Danielle Macdonald, Awkwafina, E...
# ...

# %% [markdown]
# # Q.5. Show only the Titles of all TV Shows that were released in India only.

# %% [markdown]
# Filtering

# %%
df[ (df['type']=='TV Show') & (df['country']=='India') ] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# # Q.6. Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df['director'].value_counts().head(10)
# Out:
# information is not avilable    2634
# Rajiv Chilaka                    19
# Raúl Campos, Jan Suter           18
# Suhas Kadav                      16
# Marcus Raboy                     16
# Jay Karas                        14
# Cathy Garcia-Molina              13
# Jay Chapman                      12
# Youssef Chahine                  12
# Martin Scorsese                  12
# Name: director, dtype: int64

# %% [markdown]
# # Q.7. Show all the Records, where "type is Movie and genres is Comedies" or "Country is United Kingdom".

# %%
df[ (df['type']=='Movie') & (df['listed_in']=='Comedies') ]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
df[ (df['type']=='Movie') & (df['listed_in']=='Comedies') | (df['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#                          director  \
# 8                 Andy Devonshire
# 27                   Dennis Dugan
# 32    information is not avilable
# 65    information is not avilable
# 72    information is not avilable
# ...

# %% [markdown]
# # Q.8. In how many movies/shows, Tom Cruise was cast ?

# %%
df[df['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# # Q.9. What are the different Ratings defined by Netflix ?

# %% [markdown]
# unique()

# %%
df['rating'].nunique()
# Out:
# 17

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q.9.1. How many Movies got the 'TV-14' rating, in Canada ?

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14')].shape
# Out:
# (1427, 12)

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14') & (df['country']=='Canada')].shape
# Out:
# (13, 12)

# %% [markdown]
# # Q.9.2. How many TV Show got the 'R' rating, after year 2018 ?

# %%
df[(df['type']=='TV Show') & (df['rating']=='R')]
# Out:
#      show_id     type                                title  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version
# 7593   s7594  TV Show                                Nobel
#
#                          director  \
# 3893            Quentin Tarantino
# 7593  information is not avilable
#
#                                                    cast        country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...         Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 3893  Trapped at a stagecoach stop as a storm rages ...
# ...

# %%
df[(df['type']=='TV Show') & (df['rating']=='R') & (df['release_year'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # Q.10.Show most given rating on netflix Using pie chart.

# %%
df['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(50,8))
plt.show()

# %% [markdown]
# # Q.11. What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %%
df[['Minutes', 'Unit']] = df['duration'].str.split(' ', expand = True)

# %%
df['Minutes']=df['Minutes'].astype('int')

# %%
df
# Out:
#      show_id     type                  title                     director  \
# 0         s1    Movie   Dick Johnson Is Dead              Kirsten Johnson
# 1         s2  TV Show          Blood & Water  information is not avilable
# 2         s3  TV Show              Ganglands              Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  information is not avilable
# 4         s5  TV Show           Kota Factory  information is not avilable
# ...      ...      ...                    ...                          ...
# 8802   s8803    Movie                 Zodiac                David Fincher
# 8803   s8804  TV Show            Zombie Dumb  information is not avilable
# 8804   s8805    Movie             Zombieland              Ruben Fleischer
# 8805   s8806    Movie                   Zoom                 Peter Hewitt
# 8806   s8807    Movie                 Zubaan                  Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
df['Minutes'].max()
# Out:
# 312

# %%
df['Minutes'].min()
# Out:
# 1

# %% [markdown]
# # Q.12. Which individual country has the Highest No. of TV Shows ?

# %%
df_tvshow = df[df['type'] == 'TV Show']

# %%
df_tvshow.country.value_counts()
# Out:
# United States                                    1151
# United Kingdom                                    213
# Japan                                             169
# South Korea                                       158
# India                                              79
#                                                  ...
# Belarus                                             1
# United Kingdom, Australia                           1
# France, Australia, Germany                          1
# Australia, New Zealand, United States               1
# United States, France, South Korea, Indonesia       1
# Name: country, Length: 196, dtype: int64

# %%
df_tvshow.country.value_counts().head(1)
# Out:
# United States    1151
# Name: country, dtype: int64

# %% [markdown]
# # Q.13.Top 10 Artist present on Netflix.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = df["cast"].value_counts().head(10).index,
            y = df["cast"].value_counts().head(10).values)
plt.xticks(rotation=80)
plt.title("Top10 Artist present on Netflix",fontweight="bold")
plt.show()

# %% [markdown]
# # Q.14. How can we sort the dataset by Year ?

# %%
df.sort_values(by = 'release_year')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250  information is not avilable
# 7790                  Frank Capra
# ...

# %%
df.sort_values(by = 'release_year', ascending = False).head(10)
# Out:
#     show_id     type                                  title  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens
# 781    s782    Movie  Black Holes | The Edge of All We Know
# 762    s763    Movie                           Sweet & Sour
# 763    s764  TV Show                            Sweet Tooth
# 764    s765    Movie           Trippin' with the Kandasamys
# 765    s766    Movie                                 Xtreme
# 766    s767    Movie                Alan Saldaña: Locked Up
# 767    s768  TV Show                   Creator's File: GOLD
# 768    s769    Movie                         Dancing Queens
# 770    s771    Movie              Myriam Fares: The Journey
#
#                         director  \
# 693               Lucky Kuswandi
# 781                Peter Galison
# 762                Lee Kae-byeok
# 763  information is not avilable
# 764                Jayan Moodley
# 765              Daniel Benmayor
# 766                    Alex Díaz
# ...

# %% [markdown]
# # Q.15. Find all the instances where :
# #      Category is 'Movie' and Type is 'Dramas'
# #      or
# #     Category is 'TV Show' & Type is 'Kids' TV'

# %%
df [ (df['type']=='Movie') & (df['listed_in']=='Dramas') ].head(2)
# Out:
#     show_id   type               title         director  \
# 112    s113  Movie               Worth   Sara Colangelo
# 129    s130  Movie  An Unfinished Life  Lasse Hallström
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
#
#                     country         date_added  release_year rating duration  \
# 112           United States  September 3, 2021          2021  PG-13  119 min
# 129  Germany, United States  September 1, 2021          2005  PG-13  108 min
#
#     listed_in                                        description  Minutes Unit
# 112    Dramas  In the wake of the Sept. 11 attacks, a lawyer ...      119  min
# 129    Dramas  A grieving widow and her daughter move in with...      108  min

# %%
df [ (df['type']=='TV Show') & (df['listed_in']== "Kids' TV") ]
# Out:
#      show_id     type                    title                     director  \
# 34       s35  TV Show  Tayo and Little Wizards  information is not avilable
# 39       s40  TV Show             Chhota Bheem  information is not avilable
# 65       s66  TV Show             Numberblocks  information is not avilable
# 89       s90  TV Show              Mighty Raju  information is not avilable
# 100     s101  TV Show  Tobot Galaxy Detectives  information is not avilable
# ...      ...      ...                      ...                          ...
# 8669   s8670  TV Show            V.R. Troopers  information is not avilable
# 8679   s8680  TV Show       ViR: The Robot Boy  information is not avilable
# 8783   s8784  TV Show                     Yoko  information is not avilable
# 8785   s8786  TV Show                      YOM  information is not avilable
# 8797   s8798  TV Show                Zak Storm  information is not avilable
#
# ...

# %%
df [ (df['type']=='Movie') & (df['listed_in']=='Dramas') | (df['type']=='TV Show') & (df['listed_in']== "Kids' TV") ]
# Out:
#      show_id     type                    title                     director  \
# 34       s35  TV Show  Tayo and Little Wizards  information is not avilable
# 39       s40  TV Show             Chhota Bheem  information is not avilable
# 65       s66  TV Show             Numberblocks  information is not avilable
# 89       s90  TV Show              Mighty Raju  information is not avilable
# 100     s101  TV Show  Tobot Galaxy Detectives  information is not avilable
# ...      ...      ...                      ...                          ...
# 8691   s8692    Movie                Wakefield                Robin Swicord
# 8696   s8697    Movie                War Horse             Steven Spielberg
# 8783   s8784  TV Show                     Yoko  information is not avilable
# 8785   s8786  TV Show                      YOM  information is not avilable
# 8797   s8798  TV Show                Zak Storm  information is not avilable
#
# ...

# %% [markdown]
# # Q.16. In how many movies/shows, kriti sannon was cast ?

# %%
df[df['cast'].str.contains('Kriti Sanon')]
# Out:
#      show_id   type                         title             director  \
# 387     s388  Movie                          Mimi        Laxman Utekar
# 2916   s2917  Movie  Panipat - The Great Betrayal   Ashutosh Gowariker
# 3765   s3766  Movie                   Luka Chuppi        Laxman Utekar
# 4690   s4691  Movie             Bareilly Ki Barfi  Ashwiny Iyer Tiwari
# 5616   s5617  Movie                       Dilwale         Rohit Shetty
#
#                                                    cast        country  \
# 387   Kriti Sanon, Pankaj Tripathi, Sai Tamhankar, M...  United States
# 2916  Sanjay Dutt, Arjun Kapoor, Kriti Sanon, Zeenat...          India
# 3765  Kartik Aaryan, Kriti Sanon, Pankaj Tripathi, V...          India
# 4690  Ayushmann Khurrana, Kriti Sanon, Rajkummar Rao...          India
# 5616  Shah Rukh Khan, Kajol, Kriti Sanon, Kabir Bedi...          India
#
#              date_added  release_year rating duration  \
# ...

# %% [markdown]
# # Q.17.Top10 Genre in Movies and TV Shows.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = df["listed_in"].value_counts().head(10).index,
            y = df["listed_in"].value_counts().head(10).values)
plt.xticks(rotation=80)
plt.title("Top10 Genre in Movies",fontweight="bold")
plt.show()

# %% [markdown]
# # Q.18. How many movies/shows was direct by Rohit Shetty ?

# %%
df[df['director'].str.contains('Rohit Shetty')]
# Out:
#      show_id   type                   title      director  \
# 301     s302  Movie         Chennai Express  Rohit Shetty
# 1679   s1680  Movie                 Singham  Rohit Shetty
# 1940   s1941  Movie         Golmaal Returns  Rohit Shetty
# 5616   s5617  Movie                 Dilwale  Rohit Shetty
# 6870   s6871  Movie  Golmaal: Fun Unlimited  Rohit Shetty
#
#                                                    cast country  \
# 301   Shah Rukh Khan, Deepika Padukone, Nikitin Dhee...   India
# 1679  Ajay Devgn, Kajal Aggarwal, Prakash Raj, Sonal...   India
# 1940  Ajay Devgn, Kareena Kapoor, Arshad Warsi, Tuss...   India
# 5616  Shah Rukh Khan, Kajol, Kriti Sanon, Kabir Bedi...   India
# 6870  Ajay Devgn, Tusshar Kapoor, Arshad Warsi, Shar...   India
#
#               date_added  release_year rating duration  \
# 301       August 5, 2021          2013  TV-14  135 min
# 1679   November 19, 2020          2011  TV-14  142 min
# 1940  September 28, 2020          2008  TV-MA  135 min
# ...

# %% [markdown]
# # Q.19. Tv Shows of Egypt?

# %%
df[ (df['type']=='TV Show') & (df['country']=='Egypt') ] ['title']
# Out:
# 1201    Abla Fahita: Drama Queen
# 1229                      My Way
# 1570            Once Upon a Time
# 1658                   Valentino
# 1737                  Paranormal
# 4022                 More to Say
# 4023       The Land of Hypocrisy
# 4026              Eugenie Nights
# 4027                This Evening
# 4030               Disappearance
# 4125    The Last of the Schmucks
# 4126               Hidden Worlds
# 4130                       Tayee
# 4984          Secret of the Nile
# Name: title, dtype: object

# %% [markdown]
# # Q.20.List down title whose genres is Kids'TV and country is Russia.

# %%
df [ (df['type']=='TV Show') & (df['listed_in']== "Kids' TV") & (df['country']=='Russia') ]
# Out:
#      show_id     type               title                     director  \
# 153     s154  TV Show          Kid-E-Cats  information is not avilable
# 2583   s2584  TV Show  Masha and the Bear  information is not avilable
# 6258   s6259  TV Show         Be-Be-Bears  information is not avilable
# 7131   s7132  TV Show          JingleKids  information is not avilable
#
#                                                    cast country  \
# 153   Lori Gardner, Kate Bristol, Billy Bob Thompson...  Russia
# 2583  Alina Kukushkina, Boris Kutnevich, Giselle Nie...  Russia
# 6258                Nataliya Medvedeva, Polina Kutepova  Russia
# 7131                               Tom criuse,Tom Ellis  Russia
#
#              date_added  release_year rating   duration listed_in  \
# 153   September 1, 2021          2016   TV-Y  2 Seasons  Kids' TV
# 2583        May 1, 2020          2019   TV-Y  4 Seasons  Kids' TV
# 6258    August 29, 2018          2018   TV-Y   1 Season  Kids' TV
# ...

# %% [markdown]
# # Q.21.Movie duration by year.

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,20))
plt.scatter(df['release_year'],df['Minutes'])
plt.title('Movie Duration by Year of Release')
plt.show()

# %% [markdown]
# # conclusion :
#   Direct of The conjuring movie is James wan and show id is 1283.
#   Highest number of Tv shows and movie is realeased in 2018.
#   Average Time of movies and tv shows is between 50 to 150 minutes.
#   Most given rating on netflix is TV-MA which is 36.5%
#   Moset longest show is of 315 min and Min show is of 1 min.
#   Most watched Gener is of Dramas and international Movies.
